# %% [markdown]
# # Happiness Score Prediction

# %%
import pandas as pd
import numpy as np

# %%
#loading the dataset

df=pd.read_csv('happiness.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#checking for null values

df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#checking data type

df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.scatterplot('Standard Error','Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.scatterplot('Economy (GDP per Capita)','Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
sns.scatterplot('Family','Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %%
sns.scatterplot('Health (Life Expectancy)','Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
sns.scatterplot('Freedom','Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.scatterplot('Trust (Government Corruption)','Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
sns.scatterplot('Generosity','Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %%
sns.scatterplot('Dystopia Residual','Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %% [markdown]
# - from the above figures it can be seen that how the data is distributed with respect to our target variable.

# %%
sns.pairplot(df)

# %% [markdown]
# -it can be seen that how the data is skewed for some columns and how it is distributed in several ranges.

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#trasforming categorical data to check the correlation

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

list1=['Country','Region']
for val in list1:
    df[val]=le.fit_transform(df[val])

# %%
df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
#size of canvas
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='Black',fmt='.2%')
# Out:
# <AxesSubplot:>

# %%
#describing the dataset

df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %% [markdown]
# from this we can conclude that:
# -mean for column like 'Economy (GDP per Capita)' is less than it's median so there might be skewness present in such coulmns.
# -the difference between max and third quantile is not pretty much for mostly columns, excluding coulmns like 'Country'
#  as the have categorical type data and have very weak correlation too.

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt='.2f')
plt.xticks(fontsize=18)
plt.xticks(fontsize=12)
plt.title('Variable Summary')
# Out:
# Text(0.5, 1.0, 'Variable Summary')

# %% [markdown]
# # data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    int32
#  1   Region                         158 non-null    int32
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
#dropping these column as they have very weak correlation bond with target variable

df.drop(['Happiness Rank','Standard Error','Country','Region'],axis=1,inplace=True)

# %%
df
# Out:
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# 2              7.527                   1.32548  1.36058
# 3              7.522                   1.45900  1.33095
# 4              7.427                   1.32629  1.32261
# ..               ...                       ...      ...
# 153            3.465                   0.22208  0.77370
# 154            3.340                   0.28665  0.35386
# 155            3.006                   0.66320  0.47489
# 156            2.905                   0.01530  0.41587
# 157            2.839                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
#checking for outliers

from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
np.where(z>3)
# Out:
# (array([ 27, 128, 147, 153, 155, 157], dtype=int64),
#  array([5, 6, 2, 5, 7, 2], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (152, 8)

# %%
df.shape
# Out:
# (158, 8)

# %%
print((158-152)/158*100)
# Out:
# 3.79746835443038

# %%
#selecting feature and target variable

x=df.iloc[:,1:]
y=df.iloc[:,1]

# %%
x
# Out:
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
y
# Out:
# 0      1.39651
# 1      1.30232
# 2      1.32548
# 3      1.45900
# 4      1.32629
#         ...
# 153    0.22208
# 154    0.28665
# 155    0.66320
# 156    0.01530
# 157    0.20868
# Name: Economy (GDP per Capita), Length: 158, dtype: float64

# %%
x.shape
# Out:
# (158, 7)

# %%
y.shape
# Out:
# (158,)

# %%
#checking skewness

x.skew()
# Out:
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
-threshold is +/- 0.75
- it can be seen that Family, Trust(Government corruption) and Generosity columns are exceeding threshold limit forr skewness

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
#using power transform for skewness removal:

from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

pd.DataFrame(x).skew()
# Out:
# 0   -0.127233
# 1   -0.169651
# 2   -0.183181
# 3   -0.080728
# 4    0.185965
# 5    0.013320
# 6    0.022925
# dtype: float64

# %%
#scaling the input data

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
#as the response variable is of continuous type it is a regression problem

lr=LinearRegression()

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.20)
    lr.fit(x_train,y_train)
    predtrain=lr.predict(x_train)
    predtest=lr.predict(x_test)
    if round(r2_score(predtrain,y_train)*100,2)==round(r2_score(predtest,y_test)*100,2):
        print('At random state',i,'the model performs very well')
        print('At random state',i,':')
        print('Training accuracy score is',r2_score(predtrain,y_train)*100)
        print('Testing accuracy score is',r2_score(predtest,y_test)*100,'\n')
# Out:
# At random state 12 the model performs very well
# At random state 12 :
# Training accuracy score is 99.68866961053926
# Testing accuracy score is 99.6881802843798
#
# At random state 39 the model performs very well
# At random state 39 :
# Training accuracy score is 99.69380949969334
# Testing accuracy score is 99.68599461910784
#
# At random state 71 the model performs very well
# At random state 71 :
# Training accuracy score is 99.69382775306867
# Testing accuracy score is 99.69338788477323
#
# At random state 96 the model performs very well
# At random state 96 :
# Training accuracy score is 99.69264672379036
# Testing accuracy score is 99.68624290463768
#
# At random state 243 the model performs very well
# At random state 243 :
# Training accuracy score is 99.69112125686203
# Testing accuracy score is 99.69453067134559
#
# At random state 249 the model performs very well
# At random state 249 :
# Training accuracy score is 99.69480226181099
# ...

# %%
#so using state as 71 only:

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=71,test_size=.20)
lr.fit(x_train,y_train)
predtest=lr.predict(x_test)

# %%
from sklearn.model_selection import cross_val_score

for j in range(2,11):
    lss=cross_val_score(lr,x,y,cv=j)
    lsc=lss.mean()
    print('At cv=',j)
    print('Cross Validation Score is:',lsc*100)
    print('Accuracy score is:',r2_score(predtest,y_test)*100,'\n')
# Out:
# At cv= 2
# Cross Validation Score is: 95.50878749824645
# Accuracy score is: 99.69338788477323
#
# At cv= 3
# Cross Validation Score is: 97.80150563031573
# Accuracy score is: 99.69338788477323
#
# At cv= 4
# Cross Validation Score is: 97.40874950769796
# Accuracy score is: 99.69338788477323
#
# At cv= 5
# Cross Validation Score is: 98.3981753422281
# Accuracy score is: 99.69338788477323
#
# At cv= 6
# Cross Validation Score is: 98.75155316025796
# Accuracy score is: 99.69338788477323
#
# At cv= 7
# Cross Validation Score is: 98.72378427998999
# Accuracy score is: 99.69338788477323
#
# At cv= 8
# Cross Validation Score is: 98.65243019637109
# Accuracy score is: 99.69338788477323
#
# At cv= 9
# Cross Validation Score is: 98.7644107359566
# Accuracy score is: 99.69338788477323
#
# At cv= 10
# Cross Validation Score is: 98.45217923070113
# Accuracy score is: 99.69338788477323

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predtest,color='r')
plt.plot(predtest,y_test,color='b')
plt.xlabel('Actual Happiness Score',fontsize=14)
plt.ylabel('Predicted Happiness Score',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %% [markdown]
# # Regularization:

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls=Lasso(alpha=.001,random_state=0)
ls.fit(x_train,y_train)
lspred=ls.predict(x_test)
lss=r2_score(y_test,lspred)
lss*100
# Out:
# 99.69989493707453

# %%
lcross=cross_val_score(ls,x,y,cv=10)
lfinal=lcross.mean()

# %%
lfinal
# Out:
# 0.9848900248312058

# %%
from sklearn.metrics import mean_squared_error

print(mean_squared_error(predtest,y_test))
# Out:
# 0.0004847171124855442

# %% [markdown]
# # Ensemble technique:

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)

rfscore=r2_score(y_test,predrf)

print('r2_score:',rfscore*100)

rfcscore=cross_val_score(rf,x,y,cv=5)
rfc=rfcscore.mean()
print('Cross Validation Score:',rfc*100)
# Out:
# r2_score: 99.90932118682763
# Cross Validation Score: 97.64904308225007

# %%
#so our model is performing most well with regularization techniques:

preddf=pd.DataFrame({'Original Score':y_test,'Predicted Score':lspred})
preddf
# Out:
#      Original Score  Predicted Score
# 84          0.47038         0.458329
# 49          1.25114         1.270854
# 77          0.65435         0.634709
# 47          0.86402         0.840694
# 132         0.42250         0.421805
# 126         0.76821         0.758094
# 65          1.20806         1.206387
# 59          1.12555         1.131541
# 4           1.32629         1.328094
# 121         0.19073         0.214376
# 35          1.23011         1.246031
# 122         0.33024         0.337737
# 143         0.06940         0.122091
# 44          1.16891         1.180386
# 50          0.68133         0.659973
# 131         0.83524         0.805753
# 85          1.04345         1.045391
# 139         0.23906         0.254558
# 60          1.12486         1.113230
# 53          1.12254         1.122743
# 83          0.89012         0.884931
# 155         0.66320         0.622574
# 34          1.39541         1.416573
# 86          0.92053         0.910282
# ...

# %%
print('The Model is performing very well')
print('with accuracy score:',lss*100)
print('cross validation score:',lfinal*100)
print('mean squared error:',mean_squared_error(lspred,y_test))
# Out:
# The Model is performing very well
# with accuracy score: 99.69989493707453
# cross validation score: 98.48900248312059
# mean squared error: 0.0004655001254627082

# %%
import pickle
filename='happiness_score.pkl'
pickle.dump(ls,open(filename,'wb'))
